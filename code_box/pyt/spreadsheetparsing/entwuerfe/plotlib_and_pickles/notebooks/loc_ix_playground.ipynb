# %%
## Import necessary modules
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import AutoDateFormatter, AutoDateLocator, WeekdayLocator, MonthLocator, DateFormatter
from matplotlib.dates import MO, TU, WE, TH, FR, SA, SU
from matplotlib.ticker import AutoMinorLocator
import numpy as np
import datetime, calendar
# %matplotlib tk


## Import data frome pickle generated from hotline_daily.py
data = pd.read_pickle('pickle_hotline_0904.pkl')

# %%
def rearrange(df):
    index_filter=df.loc[['tix']] ## select all hours-index rows
    
    hourse=list(range(0,25))  ## these is from 0 to 24 (25 entries!) and maps the hour indices
    mh=index_filter[hourse]  ## columns with half- and hour steps were named 0-24
    oldcols=mh.columns.values.tolist() ## list of the names of the hourse
    newcols=mh.loc['tix'].drop_duplicates().loc['tix'].values.tolist() ## one row of the hour indices provides the new column names
    cols=dict(zip(oldcols,newcols)) ## old column names get mapped to new columns names

    mhnew=df.rename(columns=cols).drop('tix') ## new dataframe has the old 'tix' entries as column names; 'tix' rows are dropped since not needed any more
    mhnew=mhnew.reset_index().set_index(['xlday']).rename(columns={'index':'status'}) ## new index will be the excel date numbers, old index is moved to a column named 'status'
    
    return mhnew

# %%
def timerange(*,df, years, months=range(1,13), weeks=range(1,53), weekdays=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']):
    resultat=df.loc[(df['year'].isin(years)) & (df['month'].isin(months)) & (df['weekday'].isin(weekdays))]
    return resultat

# %% [markdown]
# # end of function definitions

# %%
ndata=rearrange(data)
#ndata.head()

# %% [markdown]
# ### time range filter:
# Arguments must be passed as a list or as a range. Example:
#
# **timerange(df=ndata,years=[2016,2017],months=[3],weeks=[6],weekdays=['Sun','Sun'])**
#
# Note the double entry for a single weekday!
# Leaving parameters empty gives default values (=all). Months and Weeks may be mutually exclusive and raise exceptions

# %%
plotframe = timerange(df=ndata,years=[2017],months=[3])

# %%
plotframe
# Out:
#                status  month  year 00:00-00:30 00:30-01:30 01:30-02:30  \
# xlday
# 42795.0    angekommen      3  2017           0           0           0
# 42795.0     verbunden      3  2017           0           0           0
# 42795.0      verloren      3  2017           0           0           0
# 42795.0  servicelevel      3  2017         NaN         NaN         NaN
# 42796.0    angekommen      3  2017           0           0           0
# 42796.0     verbunden      3  2017           0           0           0
# 42796.0      verloren      3  2017           0           0           0
# 42796.0  servicelevel      3  2017         NaN         NaN         NaN
# 42797.0    angekommen      3  2017           0           0           0
# 42797.0     verbunden      3  2017           0           0           0
# 42797.0      verloren      3  2017           0           0           0
# 42797.0  servicelevel      3  2017         NaN         NaN         NaN
# 42798.0    angekommen      3  2017           0           0           0
# 42798.0     verbunden      3  2017           0           0           0
# 42798.0      verloren      3  2017           0           0           0
# 42798.0  servicelevel      3  2017         NaN         NaN         NaN
# 42799.0    angekommen      3  2017           0           0           0
# 42799.0     verbunden      3  2017           0           0           0
# 42799.0      verloren      3  2017           0           0           0
# 42799.0  servicelevel      3  2017         NaN         NaN         NaN
# 42800.0    angekommen      3  2017           0           0           0
# 42800.0     verbunden      3  2017           0           0           0
# 42800.0      verloren      3  2017           0           0           0
# 42800.0  servicelevel      3  2017         NaN         NaN         NaN
# 42801.0    angekommen      3  2017           0           0           0
# 42801.0     verbunden      3  2017           0           0           0
# 42801.0      verloren      3  2017           0           0           0
# 42801.0  servicelevel      3  2017         NaN         NaN         NaN
# 42802.0    angekommen      3  2017           0           0           0
# 42802.0     verbunden      3  2017           0           0           0
# ...               ...    ...   ...         ...         ...         ...
# 42818.0      verloren      3  2017           0           0           0
# 42818.0  servicelevel      3  2017         NaN         NaN         NaN
# 42819.0    angekommen      3  2017           0           0           0
# 42819.0     verbunden      3  2017           0           0           0
# 42819.0      verloren      3  2017           0           0           0
# 42819.0  servicelevel      3  2017         NaN         NaN         NaN
# 42820.0    angekommen      3  2017           0           0           0
# 42820.0     verbunden      3  2017           0           0           0
# 42820.0      verloren      3  2017           0           0           0
# 42820.0  servicelevel      3  2017         NaN         NaN         NaN
# 42821.0    angekommen      3  2017           0           0           0
# 42821.0     verbunden      3  2017           0           0           0
# 42821.0      verloren      3  2017           0           0           0
# 42821.0  servicelevel      3  2017         NaN         NaN         NaN
# 42822.0    angekommen      3  2017           0           0           0
# 42822.0     verbunden      3  2017           0           0           0
# 42822.0      verloren      3  2017           0           0           0
# 42822.0  servicelevel      3  2017         NaN         NaN         NaN
# 42823.0    angekommen      3  2017           0           0           0
# 42823.0     verbunden      3  2017           0           0           0
# 42823.0      verloren      3  2017           0           0           0
# 42823.0  servicelevel      3  2017         NaN         NaN         NaN
# 42824.0    angekommen      3  2017           0           0           0
# 42824.0     verbunden      3  2017           0           0           0
# 42824.0      verloren      3  2017           0           0           0
# 42824.0  servicelevel      3  2017         NaN         NaN         NaN
# 42825.0    angekommen      3  2017           0           0           0
# 42825.0     verbunden      3  2017           0           0           0
# 42825.0      verloren      3  2017           0           0           0
# 42825.0  servicelevel      3  2017         NaN         NaN         NaN
#
#         02:30-03:30 03:30-04:30 04:30-05:30 05:30-06:30   ...   19:30-20:30  \
# xlday                                                     ...
# 42795.0           0           0           0           0   ...             1
# 42795.0           0           0           0           0   ...             1
# 42795.0           0           0           0           0   ...             0
# 42795.0         NaN         NaN         NaN         NaN   ...             1
# 42796.0           0           0           0           0   ...             1
# 42796.0           0           0           0           0   ...             1
# 42796.0           0           0           0           0   ...             0
# 42796.0         NaN         NaN         NaN         NaN   ...             1
# 42797.0           0           0           0           0   ...             0
# 42797.0           0           0           0           0   ...             0
# 42797.0           0           0           0           0   ...             0
# 42797.0         NaN         NaN         NaN         NaN   ...           NaN
# 42798.0           0           0           0           0   ...             0
# 42798.0           0           0           0           0   ...             0
# 42798.0           0           0           0           0   ...             0
# 42798.0         NaN         NaN         NaN         NaN   ...           NaN
# 42799.0           0           0           0           0   ...             0
# 42799.0           0           0           0           0   ...             0
# 42799.0           0           0           0           0   ...             0
# 42799.0         NaN         NaN         NaN         NaN   ...           NaN
# 42800.0           0           0           0           0   ...             1
# 42800.0           0           0           0           0   ...             0
# 42800.0           0           0           0           0   ...             1
# 42800.0         NaN         NaN         NaN         NaN   ...             0
# 42801.0           0           0           0           0   ...             3
# 42801.0           0           0           0           0   ...             3
# 42801.0           0           0           0           0   ...             0
# 42801.0         NaN         NaN         NaN         NaN   ...             1
# 42802.0           0           0           0           0   ...             0
# 42802.0           0           0           0           0   ...             0
# ...             ...         ...         ...         ...   ...           ...
# 42818.0           0           0           0           0   ...             0
