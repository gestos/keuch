# %%
## Import necessary modules
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import AutoDateFormatter, AutoDateLocator, WeekdayLocator, MonthLocator, DateFormatter
from matplotlib.dates import MO, TU, WE, TH, FR, SA, SU
from matplotlib.ticker import AutoMinorLocator
import numpy as np
import datetime, calendar
# %matplotlib tk


## Import data frome pickle generated from hotline_daily.py
data = pd.read_pickle('./../../xls_testruns/agentenpickel.pkl')

# %%
def rearrange(df):
    index_filter=df.loc[['tix']] ## select all hours-index rows
    
    hourse=list(range(0,25))  ## these is from 0 to 24 (25 entries!) and maps the hour indices
    mh=index_filter[hourse]  ## columns with half- and hour steps were named 0-24
    oldcols=mh.columns.values.tolist() ## list of the names of the hourse
    newcols=mh.loc['tix'].drop_duplicates().loc['tix'].values.tolist() ## one row of the hour indices provides the new column names
    cols=dict(zip(oldcols,newcols)) ## old column names get mapped to new columns names

    mhnew=df.rename(columns=cols).drop('tix') ## new dataframe has the old 'tix' entries as column names; 'tix' rows are dropped since not needed any more
    mhnew=mhnew.reset_index().set_index(['xlday']).rename(columns={'index':'status'}) ## new index will be the excel date numbers, old index is moved to a column named 'status'
    
    return mhnew

# %%
def timerange(*,df, years, months=range(1,13), weeks=range(1,53), weekdays=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']):
    resultat=df.loc[(df['year'].isin(years)) & (df['month'].isin(months)) & (df['weekday'].isin(weekdays))]
    return resultat

# %% [markdown]
# # end of function definitions

# %%
#ndata=rearrange(data)
data.tail(120)
# Out:
#                                      dt    yy       tt bz  hh  dd        acw  \
# 2017-09-30 13:00:00 geyerme  2017-09-30  2017   1.1167  n  13  30          2
#                     neumath  2017-09-30  2017      1.9  n  13  30        0.1
# 2017-09-30 14:00:00 radtkke  2017-09-30  2017     1.45  n  14  30          1
#                     stanzju  2017-09-30  2017     1.55  n  14  30          1
# 2017-09-30 15:00:00 stanzju  2017-09-30  2017   2.5667  n  15  30          1
# 2017-09-30 18:00:00 stanzju  2017-09-30  2017     0.75  n  18  30     0.8333
# 2017-10-01 15:00:00 radtkke  2017-10-01  2017   0.9167  n  15   1     0.2833
# 2017-10-01 17:00:00 radtkke  2017-10-01  2017   0.1667  n  17   1          1
# 2017-10-02 06:00:00 dehnsil  2017-10-02  2017   0.4333  n   6   2     0.1334
# 2017-10-02 07:00:00 pfeifpe  2017-10-02  2017      1.7  n   7   2        0.3
#                     pletaan  2017-10-02  2017      5.1  n   7   2     2.2833
# 2017-10-02 08:00:00 beckfra  2017-10-02  2017      1.2  k   8   2     0.0667
#                     dehnsil  2017-10-02  2017      5.6  k   8   2     1.2333
#                     henniju  2017-10-02  2017   7.8833  k   8   2          1
#                     neumath  2017-10-02  2017    11.95  k   8   2        0.7
#                     gesinst  2017-10-04  2017    15.45  k  17   4     2.6167
#                     papkeda  2017-10-04  2017  13.1333  k  17   4          4
#                     steffci  2017-10-04  2017  23.5333  k  17   4     4.7334
# 2017-10-04 18:00:00 diessro  2017-10-04  2017   7.5833  k  18   4          2
#                     papkeda  2017-10-04  2017   7.2667  k  18   4     3.0333
# 2017-10-04 19:00:00 beckfra  2017-10-04  2017        3  k  19   4     0.8333
#                     gesinst  2017-10-04  2017   8.3333  k  19   4   0.450001
#
#                              mm  ww   wd lo       ag an be vl       ht
# 2017-09-30 13:00:00 geyerme   9  39  Sat  H  geyerme  2  2  0   3.1167
#                     neumath   9  39  Sat  B  neumath  2  2  0        2
# 2017-09-30 14:00:00 radtkke   9  39  Sat  H  radtkke  1  1  0     2.45
#                     stanzju   9  39  Sat  B  stanzju  1  1  0     2.55
# 2017-09-30 15:00:00 stanzju   9  39  Sat  B  stanzju  1  1  0   3.5667
# 2017-09-30 18:00:00 stanzju   9  39  Sat  B  stanzju  1  1  0   1.5833
# 2017-10-01 15:00:00 radtkke  10  39  Sun  H  radtkke  1  1  0      1.2
# 2017-10-01 17:00:00 radtkke  10  39  Sun  H  radtkke  1  1  0   1.1667
# 2017-10-02 06:00:00 dehnsil  10  40  Mon  H  dehnsil  1  1  0   0.5667
# 2017-10-02 07:00:00 pfeifpe  10  40  Mon  B  pfeifpe  2  2  0        2
#                     pletaan  10  40  Mon  B  pletaan  5  5  0   7.3833
# 2017-10-02 08:00:00 beckfra  10  40  Mon  H  beckfra  1  1  0   1.2667
#                     dehnsil  10  40  Mon  H  dehnsil  2  2  0   6.8333
#                     henniju  10  40  Mon  H  henniju  1  1  0   8.8833
#                     neumath  10  40  Mon  B  neumath  2  2  0    12.65
#                     stanzju  10  40  Mon  B  stanzju  3  3  0  10.6667
# 2017-10-02 09:00:00 dehnsil  10  40  Mon  H  dehnsil  1  1  0     5.25
#                     neumath  10  40  Mon  B  neumath  1  1  0     13.2
#                     ruschfi  10  40  Mon  B  ruschfi  1  1  0   2.1333
#                     stanzju  10  40  Mon  B  stanzju  6  6  0  26.8167
#                     steffci  10  40  Mon  B  steffci  2  2  0     7.85
# 2017-10-02 10:00:00 beckfra  10  40  Mon  H  beckfra  3  3  0    11.05
#                     dehnsil  10  40  Mon  H  dehnsil  6  6  0     21.7
#                     neumath  10  40  Mon  B  neumath  1  1  0   6.2167
#                     pletaan  10  40  Mon  B  pletaan  1  1  0   6.4167
#                     stanzju  10  40  Mon  B  stanzju  7  7  0  26.1833
#                     steffci  10  40  Mon  B  steffci  5  5  0    30.95
# 2017-10-02 11:00:00 dehnsil  10  40  Mon  H  dehnsil  1  1  0   4.5833
#                     henniju  10  40  Mon  H  henniju  1  1  0   5.0333
#                     neumath  10  40  Mon  B  neumath  2  2  0  10.2667
# ...                          ..  ..  ... ..      ... .. .. ..      ...
# 2017-10-04 13:00:00 gesinst  10  40  Wed  B  gesinst  5  5  0  19.3333
#                     geyerme  10  40  Wed  H  geyerme  4  4  0  10.1833
#                     pletaan  10  40  Wed  B  pletaan  9  9  0  27.5167
#                     steffci  10  40  Wed  B  steffci  9  9  0     31.7
# 2017-10-04 14:00:00 gesinst  10  40  Wed  B  gesinst  3  3  0     15.6
#                     geyerme  10  40  Wed  H  geyerme  7  7  0    21.65
#                     papkeda  10  40  Wed  B  papkeda  4  4  0     11.1
#                     pletaan  10  40  Wed  B  pletaan  1  1  0   3.9167
#                     steffci  10  40  Wed  B  steffci  5  4  1    11.25
# 2017-10-04 15:00:00 beckfra  10  40  Wed  H  beckfra  2  2  0     10.2
#                     gesinst  10  40  Wed  B  gesinst  9  9  0  31.6333
#                     geyerme  10  40  Wed  H  geyerme  3  3  0  11.2833
#                     henniju  10  40  Wed  H  henniju  5  5  0  29.3667
#                     papkeda  10  40  Wed  B  papkeda  5  5  0   9.1833
#                     steffci  10  40  Wed  B  steffci  7  7  0  28.8833
# 2017-10-04 16:00:00 beckfra  10  40  Wed  H  beckfra  2  2  0      8.9
#                     diessro  10  40  Wed  B  diessro  3  3  0      9.4
#                     gesinst  10  40  Wed  B  gesinst  5  5  0  14.7667
#                     geyerme  10  40  Wed  H  geyerme  2  2  0  11.0667
#                     papkeda  10  40  Wed  B  papkeda  4  4  0  16.2333
#                     steffci  10  40  Wed  B  steffci  4  4  0  27.7667
# 2017-10-04 17:00:00 beckfra  10  40  Wed  H  beckfra  3  3  0     14.7
#                     diessro  10  40  Wed  B  diessro  6  6  0  24.2167
#                     gesinst  10  40  Wed  B  gesinst  3  3  0  18.0667
#                     papkeda  10  40  Wed  B  papkeda  4  4  0  17.1333
#                     steffci  10  40  Wed  B  steffci  6  6  0  28.2667
# 2017-10-04 18:00:00 diessro  10  40  Wed  B  diessro  2  2  0   9.5833
#                     papkeda  10  40  Wed  B  papkeda  4  4  0     10.3
# 2017-10-04 19:00:00 beckfra  10  40  Wed  H  beckfra  1  1  0   3.8333
#                     gesinst  10  40  Wed  B  gesinst  3  3  0   8.7833
#
# [120 rows x 16 columns]

# %% [markdown]
# ### time range filter:
# Arguments must be passed as a list or as a range. Example:
#
# **timerange(df=ndata,years=[2016,2017],months=[3],weeks=[6],weekdays=['Sun','Sun'])**
#
# Note the double entry for a single weekday!
# Leaving parameters empty gives default values (=all). Months and Weeks may be mutually exclusive and raise exceptions

# %%
plotframe = timerange(df=ndata,years=[2017],months=[3])

# %%
plotframe
